# %%
#importing the required libraries
import pandas as pd
import numpy as ny
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/Users/Mark/Downloads/data.csv')

# %%
df.head()
# Out:
#    ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   1            7.4              0.70         0.00             1.9
# 1   2            7.8              0.88         0.00             2.6
# 2   3            7.8              0.76         0.04             2.3
# 3   4           11.2              0.28         0.56             1.9
# 4   5            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970   NaN
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4      5.0
# 1       0.68      9.8      5.0
# 2       0.65      9.8      5.0
# ...

# %%
#Get rid of all null values
df=df.dropna()

# %%
#Get rid of duplicates
df = df.drop_duplicates()

# %%
#Show 
df.head()
# Out:
#    ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   1            7.4              0.70         0.00             1.9
# 1   2            7.8              0.88         0.00             2.6
# 3   4           11.2              0.28         0.56             1.9
# 4   5            7.4              0.70         0.00             1.9
# 5   6            7.4              0.66         0.00             1.8
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
# 5      0.075                 13.0                  40.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4      5.0
# 1       0.68      9.8      5.0
# 3       0.58      9.8      6.0
# ...

# %%
#The reasons for adopting the approach above is to clean the data and ensure that the analysis is based on accurate and complete data.

# %%
#Showing the statistical inferences of the entire dataset
df.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %%
#The correlation between the columns
df.corr()
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.268371         -0.006833    -0.156712
# fixed acidity        -0.268371       1.000000         -0.256737     0.672306
# volatile acidity     -0.006833      -0.256737          1.000000    -0.551511
# citric acid          -0.156712       0.672306         -0.551511     1.000000
# residual sugar       -0.031780       0.114839          0.001336     0.143731
# chlorides            -0.119930       0.093857          0.061202     0.204294
# free sulfur dioxide   0.085616      -0.150261         -0.014598    -0.057619
# total sulfur dioxide -0.115795      -0.110992          0.074132     0.038593
# density              -0.368878       0.666876          0.022504     0.364181
# pH                    0.133390      -0.683788          0.234251    -0.543230
# sulphates            -0.127397       0.184937         -0.261872     0.313530
# ...

# %%
#Ploting the histogram on the dataset
plt.hist(df, 5)
plt.show()

# %%
df.boxplot(by='ID', column='fixed acidity', grid=False)
# Out:
# <Axes: title={'center': 'fixed acidity'}, xlabel='ID'>

# %%
#Pie chat for the entire dataset
df.sum().plot(kind='pie', y='ID')
# Out:
# <Axes: >

# %%
#Pie chat using fixed acidity
df.groupby(['fixed acidity']).sum().plot(kind='pie', y='ID')
# Out:
# <Axes: ylabel='ID'>

# %%
#Pie chat grouping it by quality
df.groupby(['quality']).sum().plot(kind='pie', y='ID')
# Out:
# <Axes: ylabel='ID'>

# %%
#Using Heat Map to show hidden inferences
df.style.background_gradient(cmap ='viridis')\
        .set_properties(**{'font-size': '20px'})
# Out:
# <style type="text/css">
# ...
